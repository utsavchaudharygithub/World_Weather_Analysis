# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config.py import g_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/r5/ztvxwh2507dbzw3svy6wgl400000gn/T/ipykernel_1908/3995811799.py in <module>
#      11 from scipy.stats import linregress
#      12 import gmaps
# ---> 13 from config.py import g_key
#
# ModuleNotFoundError: No module named 'config.py'; 'config' is not a package

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 725

# %%
# Setting list for the loop call:
city_data = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []

# define count of pass throughs
record_count = 1
set_count = 1
# Loop through all the cities in our list.
#for i in range(len(cities)):

print("Beginning Data Retrieval     ")
print("***********************")
# Out:
# Beginning Data Retrieval
# ***********************

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
 # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lavrentiya
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | kathmandu
# Processing Record 4 of Set 1 | melipilla
# Processing Record 5 of Set 1 | anadyr
# Processing Record 6 of Set 1 | namatanai
# Processing Record 7 of Set 1 | pokhara
# Processing Record 8 of Set 1 | hovd
# Processing Record 9 of Set 1 | kamenka
# Processing Record 10 of Set 1 | kuminskiy
# Processing Record 11 of Set 1 | hobart
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 14 of Set 1 | palmer
# Processing Record 15 of Set 1 | puerto ayora
# Processing Record 16 of Set 1 | kapaa
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | erzin
# Processing Record 20 of Set 1 | san quintin
# Processing Record 21 of Set 1 | den helder
# Processing Record 22 of Set 1 | cidreira
# Processing Record 23 of Set 1 | sitka
# Processing Record 24 of Set 1 | mayo
# Processing Record 25 of Set 1 | saint-francois
# Processing Record 26 of Set 1 | sazonovo
# Processing Record 27 of Set 1 | poum
# Processing Record 28 of Set 1 | kargasok
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping
# Processing Record 30 of Set 1 | ranong
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | jalu
# Processing Record 34 of Set 1 | veracruz
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | biak
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 38 of Set 1 | mataura
# Processing Record 39 of Set 1 | les escoumins
# Processing Record 40 of Set 1 | karamea
# City not found. Skipping
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | karratha
# Processing Record 44 of Set 1 | pavlivka
# Processing Record 45 of Set 1 | ballina
# Processing Record 46 of Set 1 | severo-kurilsk
# Processing Record 47 of Set 1 | chuy
# Processing Record 48 of Set 1 | cape town
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | awjilah
# Processing Record 0 of Set 2 | saint george
# Processing Record 1 of Set 2 | fortuna
# Processing Record 2 of Set 2 | resistencia
# Processing Record 3 of Set 2 | satitoa
# City not found. Skipping
# Processing Record 4 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 5 of Set 2 | haridwar
# Processing Record 6 of Set 2 | kaitangata
# Processing Record 7 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 2 | carnarvon
# Processing Record 9 of Set 2 | sao gabriel da cachoeira
# Processing Record 10 of Set 2 | mindelo
# Processing Record 11 of Set 2 | durban
# Processing Record 12 of Set 2 | bilibino
# Processing Record 13 of Set 2 | kati
# Processing Record 14 of Set 2 | bhanpuri
# Processing Record 15 of Set 2 | carbondale
# Processing Record 16 of Set 2 | tazovskiy
# Processing Record 17 of Set 2 | fare
# Processing Record 18 of Set 2 | luderitz
# Processing Record 19 of Set 2 | jinan
# Processing Record 20 of Set 2 | matamoros
# Processing Record 21 of Set 2 | pierre
# Processing Record 22 of Set 2 | avarua
# Processing Record 23 of Set 2 | ahipara
# Processing Record 24 of Set 2 | ponta do sol
# Processing Record 25 of Set 2 | bengkulu
# Processing Record 26 of Set 2 | ilulissat
# Processing Record 27 of Set 2 | jamestown
# Processing Record 28 of Set 2 | tahlequah
# Processing Record 29 of Set 2 | nikolskoye
# Processing Record 30 of Set 2 | cabo san lucas
# Processing Record 31 of Set 2 | tsihombe
# City not found. Skipping
# Processing Record 32 of Set 2 | saint-joseph
# Processing Record 33 of Set 2 | shelburne
# Processing Record 34 of Set 2 | zielona gora
# Processing Record 35 of Set 2 | coihaique
# Processing Record 36 of Set 2 | dubenskiy
# City not found. Skipping
# Processing Record 37 of Set 2 | naruja
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | klaksvik
# Processing Record 41 of Set 2 | new norfolk
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | chabahar
# Processing Record 44 of Set 2 | shimoda
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | atuona
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | mahebourg
# Processing Record 49 of Set 2 | castro
# Processing Record 0 of Set 3 | marawi
# Processing Record 1 of Set 3 | vilyuysk
# Processing Record 2 of Set 3 | eucaliptus
# Processing Record 3 of Set 3 | mar del plata
# Processing Record 4 of Set 3 | maloy
# Processing Record 5 of Set 3 | kahului
# Processing Record 6 of Set 3 | palabuhanratu
# City not found. Skipping
# Processing Record 7 of Set 3 | tunduru
# City not found. Skipping
# Processing Record 8 of Set 3 | praia
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | parsabad
# Processing Record 11 of Set 3 | nanakuli
# Processing Record 12 of Set 3 | khatanga
# Processing Record 13 of Set 3 | korla
# Processing Record 14 of Set 3 | attawapiskat
# City not found. Skipping
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | broome
# Processing Record 17 of Set 3 | vao
# Processing Record 18 of Set 3 | iqaluit
# Processing Record 19 of Set 3 | hithadhoo
# Processing Record 20 of Set 3 | busselton
# Processing Record 21 of Set 3 | rehoboth
# Processing Record 22 of Set 3 | port macquarie
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | heilbron
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | vianopolis
# Processing Record 28 of Set 3 | casa grande
# Processing Record 29 of Set 3 | corowa
# Processing Record 30 of Set 3 | kavieng
# Processing Record 31 of Set 3 | sola
# Processing Record 32 of Set 3 | mahates
# Processing Record 33 of Set 3 | kichera
# Processing Record 34 of Set 3 | muscat
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | kutum
# Processing Record 38 of Set 3 | eyl
# Processing Record 39 of Set 3 | linxia
# Processing Record 40 of Set 3 | fort nelson
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | ust-nera
# Processing Record 43 of Set 3 | harsova
# Processing Record 44 of Set 3 | bathsheba
# Processing Record 45 of Set 3 | provideniya
# Processing Record 46 of Set 3 | padang
# Processing Record 47 of Set 3 | amderma
# City not found. Skipping
# Processing Record 48 of Set 3 | atasu
# Processing Record 49 of Set 3 | maun
# Processing Record 0 of Set 4 | menomonie
# Processing Record 1 of Set 4 | kiama
# Processing Record 2 of Set 4 | norman wells
# Processing Record 3 of Set 4 | bandar-e torkaman
# City not found. Skipping
# Processing Record 4 of Set 4 | camacha
# Processing Record 5 of Set 4 | inuvik
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | key west
# Processing Record 9 of Set 4 | te anau
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | port hedland
# Processing Record 12 of Set 4 | mount gambier
# Processing Record 13 of Set 4 | lebu
# Processing Record 14 of Set 4 | donskoye
# Processing Record 15 of Set 4 | lompoc
# Processing Record 16 of Set 4 | deputatskiy
# Processing Record 17 of Set 4 | belushya guba
# City not found. Skipping
# Processing Record 18 of Set 4 | lata
# Processing Record 19 of Set 4 | lazaro cardenas
# Processing Record 20 of Set 4 | kathu
# Processing Record 21 of Set 4 | tlaxiaco
# City not found. Skipping
# Processing Record 22 of Set 4 | sampit
# Processing Record 23 of Set 4 | chokurdakh
# Processing Record 24 of Set 4 | nelson bay
# Processing Record 25 of Set 4 | barrow
# Processing Record 26 of Set 4 | kalmunai
# Processing Record 27 of Set 4 | pisco
# Processing Record 28 of Set 4 | lethem
# Processing Record 29 of Set 4 | lorengau
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | morro bay
# Processing Record 32 of Set 4 | pradopolis
# Processing Record 33 of Set 4 | kawalu
# Processing Record 34 of Set 4 | kodiak
# Processing Record 35 of Set 4 | lagos
# Processing Record 36 of Set 4 | xinqing
# Processing Record 37 of Set 4 | plonsk
# Processing Record 38 of Set 4 | tura
# Processing Record 39 of Set 4 | chernyshevskiy
# Processing Record 40 of Set 4 | salinopolis
# Processing Record 41 of Set 4 | encantado
# Processing Record 42 of Set 4 | aykhal
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | pachino
# Processing Record 45 of Set 4 | ust-kuyga
# Processing Record 46 of Set 4 | bull savanna
# Processing Record 47 of Set 4 | la rioja
# Processing Record 48 of Set 4 | clyde river
# Processing Record 49 of Set 4 | yulara
# Processing Record 0 of Set 5 | acapulco
# Processing Record 1 of Set 5 | lufkin
# Processing Record 2 of Set 5 | pinheiro machado
# Processing Record 3 of Set 5 | hegra
# Processing Record 4 of Set 5 | torbay
# Processing Record 5 of Set 5 | puerto baquerizo moreno
# Processing Record 6 of Set 5 | finschhafen
# Processing Record 7 of Set 5 | asayita
# City not found. Skipping
# Processing Record 8 of Set 5 | stornoway
# Processing Record 9 of Set 5 | bambous virieux
# Processing Record 10 of Set 5 | vestmannaeyjar
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | niksic
# Processing Record 13 of Set 5 | flinders
# Processing Record 14 of Set 5 | iralaya
# Processing Record 15 of Set 5 | yumen
# Processing Record 16 of Set 5 | victoria
# Processing Record 17 of Set 5 | oktyabrskiy
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping
# Processing Record 19 of Set 5 | makung
# City not found. Skipping
# Processing Record 20 of Set 5 | itarema
# Processing Record 21 of Set 5 | kenai
# Processing Record 22 of Set 5 | pontes e lacerda
# Processing Record 23 of Set 5 | monzon
# Processing Record 24 of Set 5 | krasnyy chikoy
# Processing Record 25 of Set 5 | cherskiy
# Processing Record 26 of Set 5 | ko samui
# Processing Record 27 of Set 5 | pangoa
# Processing Record 28 of Set 5 | serafimovich
# Processing Record 29 of Set 5 | januaria
# Processing Record 30 of Set 5 | hambantota
# Processing Record 31 of Set 5 | qaqortoq
# Processing Record 32 of Set 5 | hatillo
# Processing Record 33 of Set 5 | popondetta
# Processing Record 34 of Set 5 | marienburg
# Processing Record 35 of Set 5 | vila franca do campo
# Processing Record 36 of Set 5 | nishihara
# Processing Record 37 of Set 5 | alice springs
# Processing Record 38 of Set 5 | asau
# Processing Record 39 of Set 5 | ndende
# Processing Record 40 of Set 5 | salalah
# Processing Record 41 of Set 5 | souillac
# Processing Record 42 of Set 5 | morgan city
# Processing Record 43 of Set 5 | mato verde
# Processing Record 44 of Set 5 | inhambane
# Processing Record 45 of Set 5 | rabat
# Processing Record 46 of Set 5 | zaraza
# Processing Record 47 of Set 5 | moron
# Processing Record 48 of Set 5 | barawe
# City not found. Skipping
# Processing Record 49 of Set 5 | verkhnevilyuysk
# Processing Record 0 of Set 6 | bur gabo
# City not found. Skipping
# Processing Record 1 of Set 6 | kloulklubed
# Processing Record 2 of Set 6 | peno
# Processing Record 3 of Set 6 | richard toll
# City not found. Skipping
# Processing Record 4 of Set 6 | ypsonas
# Processing Record 5 of Set 6 | san cristobal
# Processing Record 6 of Set 6 | suleja
# Processing Record 7 of Set 6 | siocon
# Processing Record 8 of Set 6 | saint-philippe
# Processing Record 9 of Set 6 | gouyave
# Processing Record 10 of Set 6 | puerto colombia
# Processing Record 11 of Set 6 | cruden bay
# City not found. Skipping
# Processing Record 12 of Set 6 | dakar
# Processing Record 13 of Set 6 | severnyy
# Processing Record 14 of Set 6 | atambua
# Processing Record 15 of Set 6 | sangar
# Processing Record 16 of Set 6 | dikson
# Processing Record 17 of Set 6 | sambava
# Processing Record 18 of Set 6 | rincon
# Processing Record 19 of Set 6 | nhulunbuy
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | richards bay
# Processing Record 22 of Set 6 | alotau
# City not found. Skipping
# Processing Record 23 of Set 6 | sabha
# Processing Record 24 of Set 6 | aksu
# Processing Record 25 of Set 6 | nyandoma
# Processing Record 26 of Set 6 | shiraz
# Processing Record 27 of Set 6 | nangomba
# Processing Record 28 of Set 6 | tumannyy
# City not found. Skipping
# Processing Record 29 of Set 6 | mount isa
# Processing Record 30 of Set 6 | georgetown
# Processing Record 31 of Set 6 | nuuk
# Processing Record 32 of Set 6 | gualeguaychu
# Processing Record 33 of Set 6 | bridgwater
# Processing Record 34 of Set 6 | salekhard
# Processing Record 35 of Set 6 | necochea
# Processing Record 36 of Set 6 | teknaf
# Processing Record 37 of Set 6 | walvis bay
# Processing Record 38 of Set 6 | port hueneme
# Processing Record 39 of Set 6 | amga
# Processing Record 40 of Set 6 | san jeronimo
# Processing Record 41 of Set 6 | adrar
# Processing Record 42 of Set 6 | salamiyah
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | geraldton
# Processing Record 45 of Set 6 | marsh harbour
# Processing Record 46 of Set 6 | sault sainte marie
# Processing Record 47 of Set 6 | shahpur
# Processing Record 48 of Set 6 | barentsburg
# City not found. Skipping
# Processing Record 49 of Set 6 | kyabe
# Processing Record 0 of Set 7 | denau
# City not found. Skipping
# Processing Record 1 of Set 7 | los llanos de aridane
# Processing Record 2 of Set 7 | dalnerechensk
# Processing Record 3 of Set 7 | brownwood
# Processing Record 4 of Set 7 | bandarbeyla
# Processing Record 5 of Set 7 | abha
# Processing Record 6 of Set 7 | kudat
# Processing Record 7 of Set 7 | puerto ayacucho
# Processing Record 8 of Set 7 | nouadhibou
# Processing Record 9 of Set 7 | upernavik
# Processing Record 10 of Set 7 | egvekinot
# Processing Record 11 of Set 7 | tuatapere
# Processing Record 12 of Set 7 | madingou
# Processing Record 13 of Set 7 | tuggurt
# City not found. Skipping
# Processing Record 14 of Set 7 | tukrah
# Processing Record 15 of Set 7 | mirnyy
# Processing Record 16 of Set 7 | qandala
# Processing Record 17 of Set 7 | wellington
# Processing Record 18 of Set 7 | cururupu
# Processing Record 19 of Set 7 | kerema
# Processing Record 20 of Set 7 | karata
# Processing Record 21 of Set 7 | saint-ambroise
# Processing Record 22 of Set 7 | guanica
# Processing Record 23 of Set 7 | murmashi
# Processing Record 24 of Set 7 | airai
# Processing Record 25 of Set 7 | levski
# Processing Record 26 of Set 7 | morehead
# Processing Record 27 of Set 7 | chor
# Processing Record 28 of Set 7 | labutta
# City not found. Skipping
# Processing Record 29 of Set 7 | vardo
# Processing Record 30 of Set 7 | koshurnikovo
# Processing Record 31 of Set 7 | latung
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | san luis de palenque
# Processing Record 34 of Set 7 | la libertad
# Processing Record 35 of Set 7 | antananarivo
# Processing Record 36 of Set 7 | tuktoyaktuk
# Processing Record 37 of Set 7 | port elizabeth
# Processing Record 38 of Set 7 | awbari
# Processing Record 39 of Set 7 | kruisfontein
# Processing Record 40 of Set 7 | saint anthony
# Processing Record 41 of Set 7 | lalmohan
# Processing Record 42 of Set 7 | ojinaga
# Processing Record 43 of Set 7 | broken hill
# Processing Record 44 of Set 7 | gaoua
# Processing Record 45 of Set 7 | grindavik
# Processing Record 46 of Set 7 | buraydah
# Processing Record 47 of Set 7 | guerrero negro
# Processing Record 48 of Set 7 | praya
# Processing Record 49 of Set 7 | qena
# Processing Record 0 of Set 8 | cockburn town
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | caravelas
# Processing Record 3 of Set 8 | banjar
# Processing Record 4 of Set 8 | rawson
# Processing Record 5 of Set 8 | mersing
# Processing Record 6 of Set 8 | puerto escondido
# Processing Record 7 of Set 8 | batagay-alyta
# Processing Record 8 of Set 8 | karkal
# Processing Record 9 of Set 8 | koumra
# Processing Record 10 of Set 8 | mehamn
# Processing Record 11 of Set 8 | gushikawa
# Processing Record 12 of Set 8 | mao
# Processing Record 13 of Set 8 | warqla
# City not found. Skipping
# Processing Record 14 of Set 8 | jiddah
# City not found. Skipping
# Processing Record 15 of Set 8 | cayenne
# Processing Record 16 of Set 8 | isangel
# Processing Record 17 of Set 8 | contamana
# Processing Record 18 of Set 8 | ostrovnoy
# Processing Record 19 of Set 8 | weligama
# Processing Record 20 of Set 8 | naron
# Processing Record 21 of Set 8 | nybro
# Processing Record 22 of Set 8 | fengrun
# Processing Record 23 of Set 8 | gamba
# Processing Record 24 of Set 8 | vanimo
# Processing Record 25 of Set 8 | tiarei
# Processing Record 26 of Set 8 | charters towers
# Processing Record 27 of Set 8 | hay river
# Processing Record 28 of Set 8 | aflu
# City not found. Skipping
# Processing Record 29 of Set 8 | avera
# Processing Record 30 of Set 8 | tateyama
# Processing Record 31 of Set 8 | port lincoln
# Processing Record 32 of Set 8 | lagoa
# Processing Record 33 of Set 8 | westport
# Processing Record 34 of Set 8 | carutapera
# Processing Record 35 of Set 8 | sao filipe
# Processing Record 36 of Set 8 | badou
# Processing Record 37 of Set 8 | kuruman
# Processing Record 38 of Set 8 | port blair
# Processing Record 39 of Set 8 | udachnyy
# Processing Record 40 of Set 8 | opuwo
# Processing Record 41 of Set 8 | shakawe
# Processing Record 42 of Set 8 | eureka
# Processing Record 43 of Set 8 | pangkalanbuun
# Processing Record 44 of Set 8 | coquimbo
# Processing Record 45 of Set 8 | paradwip
# City not found. Skipping
# Processing Record 46 of Set 8 | hakui
# Processing Record 47 of Set 8 | bereda
# Processing Record 48 of Set 8 | emerald
# Processing Record 49 of Set 8 | la ronge
# Processing Record 0 of Set 9 | polson
# Processing Record 1 of Set 9 | aromashevo
# Processing Record 2 of Set 9 | portland
# Processing Record 3 of Set 9 | wassenberg
# Processing Record 4 of Set 9 | umzimvubu
# City not found. Skipping
# Processing Record 5 of Set 9 | imeni poliny osipenko
# Processing Record 6 of Set 9 | lasa
# Processing Record 7 of Set 9 | xuanzhou
# Processing Record 8 of Set 9 | igarka
# Processing Record 9 of Set 9 | thinadhoo
# Processing Record 10 of Set 9 | mocuba
# Processing Record 11 of Set 9 | tiksi
# Processing Record 12 of Set 9 | oriximina
# Processing Record 13 of Set 9 | weihe
# Processing Record 14 of Set 9 | bowen
# Processing Record 15 of Set 9 | bintulu
# Processing Record 16 of Set 9 | samusu
# City not found. Skipping
# Processing Record 17 of Set 9 | muli
# Processing Record 18 of Set 9 | kalianget
# Processing Record 19 of Set 9 | santa rosa
# Processing Record 20 of Set 9 | kadiri
# Processing Record 21 of Set 9 | gorin
# Processing Record 22 of Set 9 | kavaratti
# Processing Record 23 of Set 9 | majholi
# Processing Record 24 of Set 9 | srednekolymsk
# Processing Record 25 of Set 9 | plettenberg bay
# Processing Record 26 of Set 9 | poya
# Processing Record 27 of Set 9 | wanaka
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | hami
# Processing Record 30 of Set 9 | yenagoa
# Processing Record 31 of Set 9 | marseille
# Processing Record 32 of Set 9 | bogotol
# Processing Record 33 of Set 9 | senaki
# Processing Record 34 of Set 9 | berlevag
# Processing Record 35 of Set 9 | ponta delgada
# Processing Record 36 of Set 9 | labuhan
# Processing Record 37 of Set 9 | huilong
# Processing Record 38 of Set 9 | mantua
# Processing Record 39 of Set 9 | bridlington
# Processing Record 40 of Set 9 | kapuskasing
# Processing Record 41 of Set 9 | kirakira
# Processing Record 42 of Set 9 | narsaq
# Processing Record 43 of Set 9 | launceston
# Processing Record 44 of Set 9 | nizwa
# Processing Record 45 of Set 9 | kysyl-syr
# Processing Record 46 of Set 9 | nantucket
# Processing Record 47 of Set 9 | rocha
# Processing Record 48 of Set 9 | ulverstone
# Processing Record 49 of Set 9 | davila
# Processing Record 0 of Set 10 | harnosand
# Processing Record 1 of Set 10 | talnakh
# Processing Record 2 of Set 10 | san rafael
# Processing Record 3 of Set 10 | vila velha
# Processing Record 4 of Set 10 | bonavista
# Processing Record 5 of Set 10 | savannah bight
# Processing Record 6 of Set 10 | kieta
# Processing Record 7 of Set 10 | chama
# Processing Record 8 of Set 10 | thunder bay
# Processing Record 9 of Set 10 | burnie
# Processing Record 10 of Set 10 | chokwe
# Processing Record 11 of Set 10 | canon city
# Processing Record 12 of Set 10 | fukue
# Processing Record 13 of Set 10 | tabiauea
# City not found. Skipping
# Processing Record 14 of Set 10 | presidencia roque saenz pena
# Processing Record 15 of Set 10 | erdenet
# Processing Record 16 of Set 10 | sioux lookout
# Processing Record 17 of Set 10 | dawson creek
# Processing Record 18 of Set 10 | louisbourg
# City not found. Skipping
# Processing Record 19 of Set 10 | grand river south east
# City not found. Skipping
# Processing Record 20 of Set 10 | melton
# Processing Record 21 of Set 10 | kidal
# Processing Record 22 of Set 10 | malaga
# Processing Record 23 of Set 10 | hirado
# Processing Record 24 of Set 10 | timmins
# Processing Record 25 of Set 10 | antalaha
# Processing Record 26 of Set 10 | mugango
# Processing Record 27 of Set 10 | tukums
# Processing Record 28 of Set 10 | aldan
# Processing Record 29 of Set 10 | roebourne
# Processing Record 30 of Set 10 | yirol
# City not found. Skipping
# Processing Record 31 of Set 10 | slave lake
# Processing Record 32 of Set 10 | havre-saint-pierre
# Processing Record 33 of Set 10 | bitung
# Processing Record 34 of Set 10 | sibu
# Processing Record 35 of Set 10 | road town
# Processing Record 36 of Set 10 | north bend
# Processing Record 37 of Set 10 | ekhabi
# Processing Record 38 of Set 10 | nakamura
# Processing Record 39 of Set 10 | merauke
# Processing Record 40 of Set 10 | centralia
# Processing Record 41 of Set 10 | birao
# Processing Record 42 of Set 10 | berestechko
# Processing Record 43 of Set 10 | lubaczow
# Processing Record 44 of Set 10 | neuquen
# Processing Record 45 of Set 10 | khuzdar
# Processing Record 46 of Set 10 | waterfoot
# Processing Record 47 of Set 10 | bud
# Processing Record 48 of Set 10 | guayaramerin
# Processing Record 49 of Set 10 | northam
# Processing Record 0 of Set 11 | rodrigues alves
# Processing Record 1 of Set 11 | nome
# Processing Record 2 of Set 11 | longyearbyen
# Processing Record 3 of Set 11 | codrington
# Processing Record 4 of Set 11 | midland
# Processing Record 5 of Set 11 | cheuskiny
# City not found. Skipping
# Processing Record 6 of Set 11 | samana
# Processing Record 7 of Set 11 | yeppoon
# Processing Record 8 of Set 11 | sanmenxia
# Processing Record 9 of Set 11 | sisimiut
# Processing Record 10 of Set 11 | santa isabel do rio negro
# Processing Record 11 of Set 11 | esperance
# Processing Record 12 of Set 11 | ambodifototra
# City not found. Skipping
# Processing Record 13 of Set 11 | baisha
# Processing Record 14 of Set 11 | wyandotte
# Processing Record 15 of Set 11 | porto novo
# Processing Record 16 of Set 11 | aklavik
# Processing Record 17 of Set 11 | tecpan
# Processing Record 18 of Set 11 | port hardy
# Processing Record 19 of Set 11 | aranos
# Processing Record 20 of Set 11 | katherine
# Processing Record 21 of Set 11 | murray bridge
# Processing Record 22 of Set 11 | ucluelet
# Processing Record 23 of Set 11 | kyzyl-suu
# Processing Record 24 of Set 11 | hays
# Processing Record 25 of Set 11 | paita
# Processing Record 26 of Set 11 | kondinskoye
# Processing Record 27 of Set 11 | saldanha
# Processing Record 28 of Set 11 | zhanakorgan
# Processing Record 29 of Set 11 | maniwaki
# Processing Record 30 of Set 11 | cap malheureux
# Processing Record 31 of Set 11 | viedma
# Processing Record 32 of Set 11 | paamiut
# Processing Record 33 of Set 11 | santo tomas
# Processing Record 34 of Set 11 | celestun
# Processing Record 35 of Set 11 | asosa
# Processing Record 36 of Set 11 | ixtapa
# Processing Record 37 of Set 11 | kamen-rybolov
# Processing Record 38 of Set 11 | tual
# Processing Record 39 of Set 11 | visby
# Processing Record 40 of Set 11 | laje
# Processing Record 41 of Set 11 | chanika
# Processing Record 42 of Set 11 | valer
# Processing Record 43 of Set 11 | honningsvag
# Processing Record 44 of Set 11 | barao de melgaco
# Processing Record 45 of Set 11 | calama
# Processing Record 46 of Set 11 | dunda
# Processing Record 47 of Set 11 | saint simons
# Processing Record 48 of Set 11 | teacapan
# Processing Record 49 of Set 11 | beboto
# Processing Record 0 of Set 12 | mwaro
# Processing Record 1 of Set 12 | comodoro rivadavia
# Processing Record 2 of Set 12 | mataram
# Processing Record 3 of Set 12 | luwingu
# Processing Record 4 of Set 12 | goundam
# Processing Record 5 of Set 12 | kjollefjord
# Processing Record 6 of Set 12 | baykit
# Processing Record 7 of Set 12 | ulaanbaatar
# Processing Record 8 of Set 12 | luoyang
# Processing Record 9 of Set 12 | jalingo
# Processing Record 10 of Set 12 | hokitika
# Processing Record 11 of Set 12 | gogrial
# Processing Record 12 of Set 12 | maningrida
# Processing Record 13 of Set 12 | kismayo
# Processing Record 14 of Set 12 | ancud
# Processing Record 15 of Set 12 | kralendijk
# Processing Record 16 of Set 12 | sibolga
# Processing Record 17 of Set 12 | salinas
# Processing Record 18 of Set 12 | bolungarvik
# City not found. Skipping
# Processing Record 19 of Set 12 | newcastle
# Processing Record 20 of Set 12 | banda aceh
# Processing Record 21 of Set 12 | wasilla
# Processing Record 22 of Set 12 | burkhala
# City not found. Skipping
# Processing Record 23 of Set 12 | nanzhou
# Processing Record 24 of Set 12 | chicama
# Processing Record 25 of Set 12 | helong
# Processing Record 26 of Set 12 | umm lajj
# Processing Record 27 of Set 12 | fort frances
# Processing Record 28 of Set 12 | muros
# Processing Record 29 of Set 12 | the valley
# Processing Record 30 of Set 12 | odda
# Processing Record 31 of Set 12 | champerico
# Processing Record 32 of Set 12 | simao
# Processing Record 33 of Set 12 | eenhana
# Processing Record 34 of Set 12 | el carrizo
# Processing Record 35 of Set 12 | kanniyakumari
# Processing Record 36 of Set 12 | beloha
# Processing Record 37 of Set 12 | ayr
# Processing Record 38 of Set 12 | magdagachi
# Processing Record 39 of Set 12 | marrakesh
# Processing Record 40 of Set 12 | ormara
# Processing Record 41 of Set 12 | kulhudhuffushi
# Processing Record 42 of Set 12 | chingirlau
# Processing Record 43 of Set 12 | kuche
# City not found. Skipping
# Processing Record 44 of Set 12 | klyuchi
# Processing Record 45 of Set 12 | karasjok
# Processing Record 46 of Set 12 | whitehorse
# Processing Record 47 of Set 12 | pitimbu
# Processing Record 48 of Set 12 | usinsk
# Processing Record 49 of Set 12 | berdigestyakh
# Processing Record 0 of Set 13 | sombrerete
# Processing Record 1 of Set 13 | izumo
# Processing Record 2 of Set 13 | pangnirtung
# Processing Record 3 of Set 13 | lagunas
# Processing Record 4 of Set 13 | scarborough
# Processing Record 5 of Set 13 | armacao dos buzios
# City not found. Skipping
# Processing Record 6 of Set 13 | yaan
# Processing Record 7 of Set 13 | portree
# Processing Record 8 of Set 13 | tulum
# Processing Record 9 of Set 13 | vyartsilya
# Processing Record 10 of Set 13 | biloela
# Processing Record 11 of Set 13 | jinchang
# Processing Record 12 of Set 13 | saint-pierre
# Processing Record 13 of Set 13 | kiruna
# Processing Record 14 of Set 13 | quelimane
# Processing Record 15 of Set 13 | nador
# Processing Record 16 of Set 13 | dejen
# Processing Record 17 of Set 13 | port shepstone
# Processing Record 18 of Set 13 | artyk
# City not found. Skipping
# Processing Record 19 of Set 13 | santa fe
# Processing Record 20 of Set 13 | stonewall
# Processing Record 21 of Set 13 | sechura
# Processing Record 22 of Set 13 | perth
# Processing Record 23 of Set 13 | dalvik
# Processing Record 24 of Set 13 | constitucion
# Processing Record 25 of Set 13 | belyy yar
# Processing Record 26 of Set 13 | abbeville
# Processing Record 27 of Set 13 | stephenville
# Processing Record 28 of Set 13 | inirida
# Processing Record 29 of Set 13 | ngunguru
# Processing Record 30 of Set 13 | pec
# Processing Record 31 of Set 13 | nguiu
# City not found. Skipping
# Processing Record 32 of Set 13 | akalkot
# Processing Record 33 of Set 13 | sabang
# Processing Record 34 of Set 13 | sept-iles
# Processing Record 35 of Set 13 | alyangula
# Processing Record 36 of Set 13 | vestmanna
# Processing Record 37 of Set 13 | karlstad
# Processing Record 38 of Set 13 | bosaso
# Processing Record 39 of Set 13 | sulphur
# Processing Record 40 of Set 13 | bereznik
# Processing Record 41 of Set 13 | grand gaube
# Processing Record 42 of Set 13 | slavsk
# Processing Record 43 of Set 13 | zhigalovo
# Processing Record 44 of Set 13 | harjavalta
# Processing Record 45 of Set 13 | pathein
# Processing Record 46 of Set 13 | arrecife
# Processing Record 47 of Set 13 | misasi
# Processing Record 48 of Set 13 | guadalupe victoria
# Processing Record 49 of Set 13 | chirongui
# Processing Record 0 of Set 14 | vostok
# Processing Record 1 of Set 14 | mirador
# Processing Record 2 of Set 14 | venado tuerto
# Processing Record 3 of Set 14 | rawannawi
# City not found. Skipping
# Processing Record 4 of Set 14 | lakes entrance
# Processing Record 5 of Set 14 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 6 of Set 14 | hashtrud
# Processing Record 7 of Set 14 | maralal
# Processing Record 8 of Set 14 | meyungs
# City not found. Skipping
# Processing Record 9 of Set 14 | perelyub
# Processing Record 10 of Set 14 | sakakah
# Processing Record 11 of Set 14 | paso de los toros
# Processing Record 12 of Set 14 | vrangel
# Processing Record 13 of Set 14 | erenhot
# Processing Record 14 of Set 14 | mwinilunga
# Processing Record 15 of Set 14 | santa cruz
# Processing Record 16 of Set 14 | kattivakkam
# Processing Record 17 of Set 14 | kijang
# Processing Record 18 of Set 14 | pacific grove
# Processing Record 19 of Set 14 | severnoye
# Processing Record 20 of Set 14 | taltal
# Processing Record 21 of Set 14 | ivanteyevka
# Processing Record 22 of Set 14 | ratodero
# Processing Record 23 of Set 14 | tshane
# Processing Record 24 of Set 14 | sao joao da barra
# Processing Record 25 of Set 14 | puente grande
# Processing Record 26 of Set 14 | rocky mountain house
# Processing Record 27 of Set 14 | roswell
# Processing Record 28 of Set 14 | amla
# Processing Record 29 of Set 14 | quatre cocos
# Processing Record 30 of Set 14 | alta gracia
# Processing Record 31 of Set 14 | nanortalik
# Processing Record 32 of Set 14 | along
# Processing Record 33 of Set 14 | ottawa
# Processing Record 34 of Set 14 | chagda
# City not found. Skipping
# Processing Record 35 of Set 14 | mujiayingzi
# Processing Record 36 of Set 14 | touros
# Processing Record 37 of Set 14 | khor
# Processing Record 38 of Set 14 | mrirt
# City not found. Skipping
# Processing Record 39 of Set 14 | acarau
# Processing Record 40 of Set 14 | whitianga
# Processing Record 41 of Set 14 | wajid
# Processing Record 42 of Set 14 | marv dasht
# City not found. Skipping
# Processing Record 43 of Set 14 | teguise
# Processing Record 44 of Set 14 | rohnert park
# Processing Record 45 of Set 14 | samarai
# Processing Record 46 of Set 14 | kamenskoye
# City not found. Skipping
# Processing Record 47 of Set 14 | kagal
# Processing Record 48 of Set 14 | bandar
# Processing Record 49 of Set 14 | oranjemund
# Processing Record 0 of Set 15 | kyle of lochalsh
# City not found. Skipping
# Processing Record 1 of Set 15 | wahran
# City not found. Skipping
# Processing Record 2 of Set 15 | sassandra
# Processing Record 3 of Set 15 | coolum beach
# Processing Record 4 of Set 15 | canutama
# Processing Record 5 of Set 15 | staraya mayna
# Processing Record 6 of Set 15 | veraval
# Processing Record 7 of Set 15 | zhanaozen
# Processing Record 8 of Set 15 | smithers
# Processing Record 9 of Set 15 | masingbi
# Processing Record 10 of Set 15 | selenduma
# Processing Record 11 of Set 15 | raga
# Processing Record 12 of Set 15 | portel
# Processing Record 13 of Set 15 | bam
# Processing Record 14 of Set 15 | casper
# Processing Record 15 of Set 15 | tashtyp
# Processing Record 16 of Set 15 | saint-augustin
# Processing Record 17 of Set 15 | asfi
# Processing Record 18 of Set 15 | puri
# Processing Record 19 of Set 15 | keuruu
# Processing Record 20 of Set 15 | dingle
# Processing Record 21 of Set 15 | elizabeth city
# Processing Record 22 of Set 15 | pestravka
# Processing Record 23 of Set 15 | ust-tsilma
# Processing Record 24 of Set 15 | platanos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0    Lavrentiya      RU  2021-12-04 22:56:36  65.5833 -171.0000     11.68
# 1  Punta Arenas      CL  2021-12-04 22:56:36 -53.1500  -70.9167     55.51
# 2     Kathmandu      NP  2021-12-04 22:56:37  27.7167   85.3167     53.82
# 3     Melipilla      CL  2021-12-04 22:56:37 -33.7000  -71.2167     95.41
# 4        Anadyr      RU  2021-12-04 22:56:38  64.7500  177.4833     -3.50
# 5     Namatanai      PG  2021-12-04 22:56:38  -3.6667  152.4333     85.23
# 6       Pokhara      NP  2021-12-04 22:56:38  28.2333   83.9833     57.47
# 7          Hovd      MN  2021-12-04 22:56:39  48.0056   91.6419     19.20
# 8       Kamenka      RU  2021-12-04 22:56:39  51.3223   42.7678     27.75
# 9     Kuminskiy      RU  2021-12-04 22:56:40  58.6667   66.5667     33.10
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        96          49        3.09          light snow
# 1        47          20       24.16          few clouds
# 2        94          75        3.44       broken clouds
# 3        39           0        6.67           clear sky
# 4        76          75       17.90          light snow
# 5        69          82        5.73       broken clouds
# 6        56           6        3.51           clear sky
# 7        54           1        3.24           clear sky
# 8        84         100        3.96     overcast clouds
# 9        98         100       11.48                snow

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
#city_data_df.to_csv(output_data_file, index_label="City_ID")
