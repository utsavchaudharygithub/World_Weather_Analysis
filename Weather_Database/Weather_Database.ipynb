# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create 2000 random latitude and longitude coordinates 
latitudes = np.random.uniform(-90, 90, size = 2000)
longitudes = np.random.uniform(-180, 180, size = 2000)
coordinates = zip(latitudes, longitudes)
coordinates

# Add coordinates to a list 
coordinates_lst = list(coordinates)

# %%
# Create list for cities 
cities = []

# Use citipy to find nearest cities using coordinate list
for coordinate in coordinates_lst:
    city = citipy.nearest_city(coordinate[0],coordinate[1])
    city_name = city.city_name
    country_name = city.country_code
    
    # Find unique cities to add to cities list
    if city_name not in cities:
        cities.append(city_name)
    
    # See cities and contries
    # print(f'{city_name}, {country_name}')

# Count amount of unique cities
len(cities)
# Out:
# 736

# %%
# Setting list for the loop call:
city_data = []
city_lat = []
city_lng = []
city_max_temp = []
city_humidity = []
city_clouds = []
city_wind = []
city_country = []
city_date = []
city_desc= []
# define count of pass throughs
record_count = 1
set_count = 1
# Loop through all the cities in our list.
#for i in range(len(cities)):

print("Beginning Data Retrieval     ")
print("***********************")
# Out:
# Beginning Data Retrieval
# ***********************

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

# Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
# Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
# Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
# Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
 # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | lucapa
# Processing Record 2 of Set 1 | kalmunai
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | vaitupu
# City not found. Skipping
# Processing Record 6 of Set 1 | fortuna
# Processing Record 7 of Set 1 | praxedis guerrero
# Processing Record 8 of Set 1 | hirara
# Processing Record 9 of Set 1 | nikolskoye
# Processing Record 10 of Set 1 | dagana
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | hilo
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping
# Processing Record 15 of Set 1 | ishigaki
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | tabarqah
# City not found. Skipping
# Processing Record 18 of Set 1 | saleaula
# City not found. Skipping
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | karaton
# Processing Record 21 of Set 1 | ayagoz
# Processing Record 22 of Set 1 | genhe
# Processing Record 23 of Set 1 | hobart
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | walvis bay
# Processing Record 26 of Set 1 | severo-yeniseyskiy
# Processing Record 27 of Set 1 | haines junction
# Processing Record 28 of Set 1 | bereznik
# Processing Record 29 of Set 1 | neiafu
# Processing Record 30 of Set 1 | sioux lookout
# Processing Record 31 of Set 1 | mbandaka
# Processing Record 32 of Set 1 | port alfred
# Processing Record 33 of Set 1 | moindou
# Processing Record 34 of Set 1 | olafsvik
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | ahipara
# Processing Record 37 of Set 1 | havre-saint-pierre
# Processing Record 38 of Set 1 | erenhot
# Processing Record 39 of Set 1 | ust-kamchatsk
# City not found. Skipping
# Processing Record 40 of Set 1 | belushya guba
# City not found. Skipping
# Processing Record 41 of Set 1 | tromso
# Processing Record 42 of Set 1 | lao cai
# Processing Record 43 of Set 1 | barentsburg
# City not found. Skipping
# Processing Record 44 of Set 1 | victoria
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | nemuro
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | severo-kurilsk
# Processing Record 50 of Set 1 | bluff
# Processing Record 0 of Set 2 | salalah
# Processing Record 1 of Set 2 | nishihara
# Processing Record 2 of Set 2 | clyde river
# Processing Record 3 of Set 2 | mataura
# Processing Record 4 of Set 2 | chagda
# City not found. Skipping
# Processing Record 5 of Set 2 | hurricane
# Processing Record 6 of Set 2 | port hardy
# Processing Record 7 of Set 2 | hambantota
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | hofn
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | saint-joseph
# Processing Record 12 of Set 2 | smithers
# Processing Record 13 of Set 2 | yinchuan
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | winneba
# Processing Record 16 of Set 2 | nola
# Processing Record 17 of Set 2 | bonthe
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | verkhnetulomskiy
# Processing Record 20 of Set 2 | padang
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | ozernovskiy
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | loganville
# Processing Record 25 of Set 2 | elliot
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping
# Processing Record 28 of Set 2 | pevek
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | thompson
# Processing Record 31 of Set 2 | samarai
# Processing Record 32 of Set 2 | port-gentil
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | vaini
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | khon kaen
# Processing Record 38 of Set 2 | upata
# Processing Record 39 of Set 2 | provideniya
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | hokitika
# Processing Record 43 of Set 2 | moerai
# Processing Record 44 of Set 2 | oyama
# Processing Record 45 of Set 2 | bredasdorp
# Processing Record 46 of Set 2 | longyearbyen
# Processing Record 47 of Set 2 | virginia beach
# Processing Record 48 of Set 2 | mar del plata
# Processing Record 49 of Set 2 | bor
# Processing Record 0 of Set 3 | san patricio
# Processing Record 1 of Set 3 | richards bay
# Processing Record 2 of Set 3 | roshchino
# Processing Record 3 of Set 3 | pangnirtung
# Processing Record 4 of Set 3 | high level
# Processing Record 5 of Set 3 | gariaband
# Processing Record 6 of Set 3 | cumana
# Processing Record 7 of Set 3 | huilong
# Processing Record 8 of Set 3 | berlevag
# Processing Record 9 of Set 3 | tsihombe
# City not found. Skipping
# Processing Record 10 of Set 3 | goderich
# Processing Record 11 of Set 3 | kropotkin
# Processing Record 12 of Set 3 | flinders
# Processing Record 13 of Set 3 | ust-maya
# Processing Record 14 of Set 3 | sao filipe
# Processing Record 15 of Set 3 | camargo
# Processing Record 16 of Set 3 | pinotepa nacional
# Processing Record 17 of Set 3 | tuatapere
# Processing Record 18 of Set 3 | vao
# Processing Record 19 of Set 3 | pervomayskiy
# Processing Record 20 of Set 3 | upernavik
# Processing Record 21 of Set 3 | geraldton
# Processing Record 22 of Set 3 | punta arenas
# Processing Record 23 of Set 3 | senj
# Processing Record 24 of Set 3 | fort saint john
# City not found. Skipping
# Processing Record 25 of Set 3 | makung
# City not found. Skipping
# Processing Record 26 of Set 3 | paso de los toros
# Processing Record 27 of Set 3 | airai
# Processing Record 28 of Set 3 | say
# Processing Record 29 of Set 3 | wuwei
# Processing Record 30 of Set 3 | barrow
# Processing Record 31 of Set 3 | havoysund
# Processing Record 32 of Set 3 | evensk
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | mys shmidta
# City not found. Skipping
# Processing Record 35 of Set 3 | guerrero negro
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | honningsvag
# Processing Record 38 of Set 3 | puerto ayacucho
# Processing Record 39 of Set 3 | alta floresta
# Processing Record 40 of Set 3 | sitka
# Processing Record 41 of Set 3 | rocha
# Processing Record 42 of Set 3 | balykshi
# Processing Record 43 of Set 3 | tasiilaq
# Processing Record 44 of Set 3 | vardo
# Processing Record 45 of Set 3 | pinerolo
# Processing Record 46 of Set 3 | bahia honda
# Processing Record 47 of Set 3 | matara
# Processing Record 48 of Set 3 | jamestown
# Processing Record 49 of Set 3 | salamanca
# Processing Record 0 of Set 4 | cabo san lucas
# Processing Record 1 of Set 4 | buala
# Processing Record 2 of Set 4 | avera
# Processing Record 3 of Set 4 | eureka
# Processing Record 4 of Set 4 | lolua
# City not found. Skipping
# Processing Record 5 of Set 4 | alice springs
# Processing Record 6 of Set 4 | lebu
# Processing Record 7 of Set 4 | lobito
# Processing Record 8 of Set 4 | pleasanton
# Processing Record 9 of Set 4 | chernyshevskiy
# Processing Record 10 of Set 4 | gizo
# Processing Record 11 of Set 4 | saldanha
# Processing Record 12 of Set 4 | chuy
# Processing Record 13 of Set 4 | sal rei
# Processing Record 14 of Set 4 | yellowknife
# Processing Record 15 of Set 4 | fria
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | portland
# Processing Record 18 of Set 4 | chokurdakh
# Processing Record 19 of Set 4 | shestakovo
# Processing Record 20 of Set 4 | georgetown
# Processing Record 21 of Set 4 | marawi
# Processing Record 22 of Set 4 | tatarsk
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | maceio
# Processing Record 25 of Set 4 | lavrentiya
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | mount gambier
# Processing Record 29 of Set 4 | tidore
# City not found. Skipping
# Processing Record 30 of Set 4 | minna
# Processing Record 31 of Set 4 | burnie
# Processing Record 32 of Set 4 | laguna
# Processing Record 33 of Set 4 | quzhou
# Processing Record 34 of Set 4 | srednekolymsk
# Processing Record 35 of Set 4 | dwarka
# Processing Record 36 of Set 4 | saint anthony
# Processing Record 37 of Set 4 | mahebourg
# Processing Record 38 of Set 4 | menongue
# Processing Record 39 of Set 4 | staryy nadym
# Processing Record 40 of Set 4 | badulla
# Processing Record 41 of Set 4 | mamlyutka
# Processing Record 42 of Set 4 | kiomboi
# Processing Record 43 of Set 4 | north myrtle beach
# Processing Record 44 of Set 4 | valparaiso
# Processing Record 45 of Set 4 | nome
# Processing Record 46 of Set 4 | itoman
# Processing Record 47 of Set 4 | bethel
# Processing Record 48 of Set 4 | jambusar
# Processing Record 49 of Set 4 | coquimbo
# Processing Record 0 of Set 5 | karatu
# Processing Record 1 of Set 5 | spokoynaya
# Processing Record 2 of Set 5 | boa vista
# Processing Record 3 of Set 5 | hojo
# Processing Record 4 of Set 5 | los llanos de aridane
# Processing Record 5 of Set 5 | cayenne
# Processing Record 6 of Set 5 | butaritari
# Processing Record 7 of Set 5 | kamenskoye
# City not found. Skipping
# Processing Record 8 of Set 5 | wencheng
# Processing Record 9 of Set 5 | dudinka
# Processing Record 10 of Set 5 | pisco
# Processing Record 11 of Set 5 | salme
# Processing Record 12 of Set 5 | ust-tsilma
# Processing Record 13 of Set 5 | mattoon
# Processing Record 14 of Set 5 | qingdao
# Processing Record 15 of Set 5 | fairbanks
# Processing Record 16 of Set 5 | vestmannaeyjar
# Processing Record 17 of Set 5 | jumla
# Processing Record 18 of Set 5 | mandalgovi
# Processing Record 19 of Set 5 | skalistyy
# City not found. Skipping
# Processing Record 20 of Set 5 | umm lajj
# Processing Record 21 of Set 5 | cidreira
# Processing Record 22 of Set 5 | waipawa
# Processing Record 23 of Set 5 | cherskiy
# Processing Record 24 of Set 5 | seoul
# Processing Record 25 of Set 5 | leningradskiy
# Processing Record 26 of Set 5 | palmer
# Processing Record 27 of Set 5 | amderma
# City not found. Skipping
# Processing Record 28 of Set 5 | velizh
# Processing Record 29 of Set 5 | ixtapa
# Processing Record 30 of Set 5 | wanning
# Processing Record 31 of Set 5 | santa cruz del sur
# Processing Record 32 of Set 5 | gambiran
# Processing Record 33 of Set 5 | mudgee
# Processing Record 34 of Set 5 | dikson
# Processing Record 35 of Set 5 | punta alta
# Processing Record 36 of Set 5 | yulara
# Processing Record 37 of Set 5 | castro
# Processing Record 38 of Set 5 | asau
# Processing Record 39 of Set 5 | qasr hallal
# Processing Record 40 of Set 5 | broome
# Processing Record 41 of Set 5 | aqtobe
# Processing Record 42 of Set 5 | inhambane
# Processing Record 43 of Set 5 | santa cruz
# Processing Record 44 of Set 5 | manaus
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | temaraia
# City not found. Skipping
# Processing Record 47 of Set 5 | ingham
# Processing Record 48 of Set 5 | iquique
# Processing Record 49 of Set 5 | eldikan
# City not found. Skipping
# Processing Record 0 of Set 6 | port shepstone
# Processing Record 1 of Set 6 | katherine
# Processing Record 2 of Set 6 | harper
# Processing Record 3 of Set 6 | maine-soroa
# Processing Record 4 of Set 6 | tasbuget
# City not found. Skipping
# Processing Record 5 of Set 6 | bilibino
# Processing Record 6 of Set 6 | manyana
# Processing Record 7 of Set 6 | jalu
# Processing Record 8 of Set 6 | tevaitoa
# Processing Record 9 of Set 6 | burica
# City not found. Skipping
# Processing Record 10 of Set 6 | sainte-marie
# Processing Record 11 of Set 6 | kodiak
# Processing Record 12 of Set 6 | aiken
# Processing Record 13 of Set 6 | tiksi
# Processing Record 14 of Set 6 | nhulunbuy
# Processing Record 15 of Set 6 | maumere
# Processing Record 16 of Set 6 | idlib
# Processing Record 17 of Set 6 | mahadday weyne
# City not found. Skipping
# Processing Record 18 of Set 6 | bobo dioulasso
# Processing Record 19 of Set 6 | nantucket
# Processing Record 20 of Set 6 | metro
# Processing Record 21 of Set 6 | egvekinot
# Processing Record 22 of Set 6 | skjervoy
# Processing Record 23 of Set 6 | sinnamary
# Processing Record 24 of Set 6 | petropavl
# Processing Record 25 of Set 6 | mantua
# Processing Record 26 of Set 6 | luau
# Processing Record 27 of Set 6 | luderitz
# Processing Record 28 of Set 6 | dingle
# Processing Record 29 of Set 6 | bahile
# Processing Record 30 of Set 6 | edmonds
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | mae hong son
# Processing Record 33 of Set 6 | kem
# Processing Record 34 of Set 6 | ponta do sol
# Processing Record 35 of Set 6 | westpunt
# City not found. Skipping
# Processing Record 36 of Set 6 | mokhsogollokh
# Processing Record 37 of Set 6 | manggar
# Processing Record 38 of Set 6 | lasa
# Processing Record 39 of Set 6 | yumen
# Processing Record 40 of Set 6 | anadyr
# Processing Record 41 of Set 6 | lorengau
# Processing Record 42 of Set 6 | lata
# Processing Record 43 of Set 6 | ochakiv
# Processing Record 44 of Set 6 | bowen
# Processing Record 45 of Set 6 | meulaboh
# Processing Record 46 of Set 6 | semnan
# Processing Record 47 of Set 6 | faya
# Processing Record 48 of Set 6 | iwanai
# Processing Record 49 of Set 6 | de aar
# Processing Record 0 of Set 7 | mocuba
# Processing Record 1 of Set 7 | kamenka
# Processing Record 2 of Set 7 | yar-sale
# Processing Record 3 of Set 7 | dicabisagan
# Processing Record 4 of Set 7 | washington
# Processing Record 5 of Set 7 | qom
# Processing Record 6 of Set 7 | pitimbu
# Processing Record 7 of Set 7 | nakhon thai
# Processing Record 8 of Set 7 | rungata
# City not found. Skipping
# Processing Record 9 of Set 7 | sanghar
# Processing Record 10 of Set 7 | san ciro de acosta
# Processing Record 11 of Set 7 | odesskoye
# Processing Record 12 of Set 7 | port hedland
# Processing Record 13 of Set 7 | nizhneyansk
# City not found. Skipping
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | murwara
# Processing Record 17 of Set 7 | falmouth
# Processing Record 18 of Set 7 | zhuhai
# Processing Record 19 of Set 7 | zhigansk
# Processing Record 20 of Set 7 | strezhevoy
# Processing Record 21 of Set 7 | plyussa
# Processing Record 22 of Set 7 | ust-ordynskiy
# Processing Record 23 of Set 7 | kruisfontein
# Processing Record 24 of Set 7 | chandler
# Processing Record 25 of Set 7 | pokrovskoye
# Processing Record 26 of Set 7 | khash
# Processing Record 27 of Set 7 | grindavik
# Processing Record 28 of Set 7 | magnor
# Processing Record 29 of Set 7 | kallidaikurichchi
# Processing Record 30 of Set 7 | carauari
# Processing Record 31 of Set 7 | chumikan
# Processing Record 32 of Set 7 | atar
# Processing Record 33 of Set 7 | cheney
# Processing Record 34 of Set 7 | gold coast
# Processing Record 35 of Set 7 | arkhangelskoye
# Processing Record 36 of Set 7 | saskylakh
# Processing Record 37 of Set 7 | vila velha
# Processing Record 38 of Set 7 | jacareacanga
# Processing Record 39 of Set 7 | morondava
# Processing Record 40 of Set 7 | hoshcha
# Processing Record 41 of Set 7 | umm kaddadah
# Processing Record 42 of Set 7 | parbhani
# Processing Record 43 of Set 7 | conakry
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | coihaique
# Processing Record 46 of Set 7 | nueva loja
# Processing Record 47 of Set 7 | awjilah
# Processing Record 48 of Set 7 | ugoofaaru
# Processing Record 49 of Set 7 | tura
# Processing Record 0 of Set 8 | oranjemund
# Processing Record 1 of Set 8 | pella
# Processing Record 2 of Set 8 | ngukurr
# City not found. Skipping
# Processing Record 3 of Set 8 | sept-iles
# Processing Record 4 of Set 8 | chapais
# Processing Record 5 of Set 8 | skelleftea
# Processing Record 6 of Set 8 | santa isabel
# Processing Record 7 of Set 8 | mirnyy
# Processing Record 8 of Set 8 | blonduos
# City not found. Skipping
# Processing Record 9 of Set 8 | sola
# Processing Record 10 of Set 8 | pangai
# Processing Record 11 of Set 8 | aden
# Processing Record 12 of Set 8 | swan hill
# Processing Record 13 of Set 8 | nanortalik
# Processing Record 14 of Set 8 | lagoa
# Processing Record 15 of Set 8 | darhan
# Processing Record 16 of Set 8 | nuevo progreso
# Processing Record 17 of Set 8 | kotido
# Processing Record 18 of Set 8 | port augusta
# Processing Record 19 of Set 8 | ilulissat
# Processing Record 20 of Set 8 | lenine
# Processing Record 21 of Set 8 | bolungarvik
# City not found. Skipping
# Processing Record 22 of Set 8 | san ignacio
# Processing Record 23 of Set 8 | yelan
# Processing Record 24 of Set 8 | makat
# Processing Record 25 of Set 8 | tondol
# Processing Record 26 of Set 8 | katsuura
# Processing Record 27 of Set 8 | constitucion
# Processing Record 28 of Set 8 | bokovskaya
# Processing Record 29 of Set 8 | linqing
# Processing Record 30 of Set 8 | valentin gomez farias
# Processing Record 31 of Set 8 | caravelas
# Processing Record 32 of Set 8 | namtsy
# Processing Record 33 of Set 8 | hoquiam
# Processing Record 34 of Set 8 | isaka
# Processing Record 35 of Set 8 | kostomuksha
# Processing Record 36 of Set 8 | qaqortoq
# Processing Record 37 of Set 8 | attawapiskat
# City not found. Skipping
# Processing Record 38 of Set 8 | college
# Processing Record 39 of Set 8 | lima
# Processing Record 40 of Set 8 | ngunguru
# Processing Record 41 of Set 8 | broken hill
# Processing Record 42 of Set 8 | aklavik
# Processing Record 43 of Set 8 | great yarmouth
# Processing Record 44 of Set 8 | kibala
# Processing Record 45 of Set 8 | waris aliganj
# Processing Record 46 of Set 8 | norman wells
# Processing Record 47 of Set 8 | nelson bay
# Processing Record 48 of Set 8 | lazaro cardenas
# Processing Record 49 of Set 8 | ystad
# Processing Record 0 of Set 9 | kanker
# Processing Record 1 of Set 9 | rypefjord
# Processing Record 2 of Set 9 | kautokeino
# Processing Record 3 of Set 9 | taoudenni
# Processing Record 4 of Set 9 | ardabil
# Processing Record 5 of Set 9 | touros
# Processing Record 6 of Set 9 | impfondo
# Processing Record 7 of Set 9 | gat
# Processing Record 8 of Set 9 | collierville
# Processing Record 9 of Set 9 | cran-gevrier
# Processing Record 10 of Set 9 | tabiauea
# City not found. Skipping
# Processing Record 11 of Set 9 | lloydminster
# Processing Record 12 of Set 9 | shakawe
# Processing Record 13 of Set 9 | sampit
# Processing Record 14 of Set 9 | richmond
# Processing Record 15 of Set 9 | rawson
# Processing Record 16 of Set 9 | tulu bolo
# Processing Record 17 of Set 9 | faanui
# Processing Record 18 of Set 9 | makakilo city
# Processing Record 19 of Set 9 | tricase
# Processing Record 20 of Set 9 | palabuhanratu
# City not found. Skipping
# Processing Record 21 of Set 9 | kieta
# Processing Record 22 of Set 9 | nara
# Processing Record 23 of Set 9 | alugan
# Processing Record 24 of Set 9 | utete
# Processing Record 25 of Set 9 | birganj
# Processing Record 26 of Set 9 | tolaga bay
# Processing Record 27 of Set 9 | andenes
# Processing Record 28 of Set 9 | ulaanbaatar
# Processing Record 29 of Set 9 | onguday
# Processing Record 30 of Set 9 | muisne
# Processing Record 31 of Set 9 | talaya
# Processing Record 32 of Set 9 | belmonte
# Processing Record 33 of Set 9 | priargunsk
# Processing Record 34 of Set 9 | nouadhibou
# Processing Record 35 of Set 9 | vagur
# Processing Record 36 of Set 9 | tarauaca
# Processing Record 37 of Set 9 | tilichiki
# Processing Record 38 of Set 9 | tabou
# Processing Record 39 of Set 9 | tual
# Processing Record 40 of Set 9 | port hawkesbury
# Processing Record 41 of Set 9 | uvalde
# Processing Record 42 of Set 9 | yeppoon
# Processing Record 43 of Set 9 | aksarka
# Processing Record 44 of Set 9 | biak
# Processing Record 45 of Set 9 | werota
# Processing Record 46 of Set 9 | atbasar
# Processing Record 47 of Set 9 | bandarbeyla
# Processing Record 48 of Set 9 | acapulco
# Processing Record 49 of Set 9 | namibe
# Processing Record 0 of Set 10 | boyolangu
# Processing Record 1 of Set 10 | quatre cocos
# Processing Record 2 of Set 10 | bam
# Processing Record 3 of Set 10 | tall kayf
# Processing Record 4 of Set 10 | bubaque
# Processing Record 5 of Set 10 | mahajanga
# Processing Record 6 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 7 of Set 10 | barda
# Processing Record 8 of Set 10 | sovetskiy
# Processing Record 9 of Set 10 | columbus
# Processing Record 10 of Set 10 | general salgado
# Processing Record 11 of Set 10 | viligili
# City not found. Skipping
# Processing Record 12 of Set 10 | sedelnikovo
# City not found. Skipping
# Processing Record 13 of Set 10 | hennenman
# Processing Record 14 of Set 10 | alofi
# Processing Record 15 of Set 10 | roswell
# Processing Record 16 of Set 10 | charagua
# Processing Record 17 of Set 10 | tam ky
# Processing Record 18 of Set 10 | dongon
# Processing Record 19 of Set 10 | hobyo
# Processing Record 20 of Set 10 | verkhoyansk
# Processing Record 21 of Set 10 | sorong
# Processing Record 22 of Set 10 | isabela
# Processing Record 23 of Set 10 | fulton
# Processing Record 24 of Set 10 | qasigiannguit
# Processing Record 25 of Set 10 | komsomolskiy
# Processing Record 26 of Set 10 | maniitsoq
# Processing Record 27 of Set 10 | pringsewu
# Processing Record 28 of Set 10 | hithadhoo
# Processing Record 29 of Set 10 | axim
# Processing Record 30 of Set 10 | port-cartier
# Processing Record 31 of Set 10 | la primavera
# Processing Record 32 of Set 10 | ekhabi
# Processing Record 33 of Set 10 | hamilton
# Processing Record 34 of Set 10 | barcelos
# Processing Record 35 of Set 10 | labuhan
# Processing Record 36 of Set 10 | chauk
# Processing Record 37 of Set 10 | kangasala
# Processing Record 38 of Set 10 | millville
# Processing Record 39 of Set 10 | danilov
# Processing Record 40 of Set 10 | mareeba
# Processing Record 41 of Set 10 | wucheng
# Processing Record 42 of Set 10 | bathsheba
# Processing Record 43 of Set 10 | hovd
# Processing Record 44 of Set 10 | poltavka
# Processing Record 45 of Set 10 | matagami
# Processing Record 46 of Set 10 | altamira
# Processing Record 47 of Set 10 | naryan-mar
# Processing Record 48 of Set 10 | leninskoye
# Processing Record 49 of Set 10 | la ronge
# Processing Record 0 of Set 11 | soyo
# Processing Record 1 of Set 11 | marquette
# Processing Record 2 of Set 11 | buraydah
# Processing Record 3 of Set 11 | tuggurt
# City not found. Skipping
# Processing Record 4 of Set 11 | brae
# Processing Record 5 of Set 11 | kudahuvadhoo
# Processing Record 6 of Set 11 | poum
# Processing Record 7 of Set 11 | samusu
# City not found. Skipping
# Processing Record 8 of Set 11 | todos santos
# Processing Record 9 of Set 11 | sampang
# Processing Record 10 of Set 11 | rio grande
# Processing Record 11 of Set 11 | port blair
# Processing Record 12 of Set 11 | araouane
# Processing Record 13 of Set 11 | anloga
# Processing Record 14 of Set 11 | kavaratti
# Processing Record 15 of Set 11 | yambio
# Processing Record 16 of Set 11 | taunggyi
# Processing Record 17 of Set 11 | abbeville
# Processing Record 18 of Set 11 | ruteng
# Processing Record 19 of Set 11 | sur
# Processing Record 20 of Set 11 | mehamn
# Processing Record 21 of Set 11 | borujan
# City not found. Skipping
# Processing Record 22 of Set 11 | riyadh
# Processing Record 23 of Set 11 | qui nhon
# Processing Record 24 of Set 11 | pangkalanbuun
# Processing Record 25 of Set 11 | uk
# City not found. Skipping
# Processing Record 26 of Set 11 | ormara
# Processing Record 27 of Set 11 | satitoa
# City not found. Skipping
# Processing Record 28 of Set 11 | wajid
# Processing Record 29 of Set 11 | necochea
# Processing Record 30 of Set 11 | lugoba
# Processing Record 31 of Set 11 | utiroa
# City not found. Skipping
# Processing Record 32 of Set 11 | gasa
# Processing Record 33 of Set 11 | iquitos
# Processing Record 34 of Set 11 | puerto escondido
# Processing Record 35 of Set 11 | inderborskiy
# City not found. Skipping
# Processing Record 36 of Set 11 | madison heights
# Processing Record 37 of Set 11 | tautira
# Processing Record 38 of Set 11 | henties bay
# Processing Record 39 of Set 11 | bloomington
# Processing Record 40 of Set 11 | okhotsk
# Processing Record 41 of Set 11 | urazovka
# Processing Record 42 of Set 11 | saint-felix-de-valois
# Processing Record 43 of Set 11 | lac du bonnet
# Processing Record 44 of Set 11 | shadegan
# Processing Record 45 of Set 11 | raduzhnyy
# Processing Record 46 of Set 11 | sao joao da barra
# Processing Record 47 of Set 11 | galesong
# Processing Record 48 of Set 11 | goundi
# Processing Record 49 of Set 11 | hastings
# Processing Record 0 of Set 12 | genc
# Processing Record 1 of Set 12 | te anau
# Processing Record 2 of Set 12 | klyuchi
# Processing Record 3 of Set 12 | ust-kuyga
# Processing Record 4 of Set 12 | gualeguay
# Processing Record 5 of Set 12 | udachnyy
# Processing Record 6 of Set 12 | along
# Processing Record 7 of Set 12 | rognan
# Processing Record 8 of Set 12 | rodrigues alves
# Processing Record 9 of Set 12 | dolbeau
# City not found. Skipping
# Processing Record 10 of Set 12 | puerto maldonado
# Processing Record 11 of Set 12 | bayevo
# Processing Record 12 of Set 12 | elizabeth city
# Processing Record 13 of Set 12 | klaksvik
# Processing Record 14 of Set 12 | calvinia
# Processing Record 15 of Set 12 | candelaria
# Processing Record 16 of Set 12 | ahuimanu
# Processing Record 17 of Set 12 | fuyu
# Processing Record 18 of Set 12 | khani
# Processing Record 19 of Set 12 | shimoda
# Processing Record 20 of Set 12 | noshiro
# Processing Record 21 of Set 12 | tarata
# Processing Record 22 of Set 12 | igarka
# Processing Record 23 of Set 12 | sangar
# Processing Record 24 of Set 12 | fort nelson
# Processing Record 25 of Set 12 | kahului
# Processing Record 26 of Set 12 | julio de castilhos
# Processing Record 27 of Set 12 | banda aceh
# Processing Record 28 of Set 12 | puerto carreno
# Processing Record 29 of Set 12 | sakakah
# Processing Record 30 of Set 12 | danilovka
# Processing Record 31 of Set 12 | irbil
# Processing Record 32 of Set 12 | narsaq
# Processing Record 33 of Set 12 | khromtau
# Processing Record 34 of Set 12 | minden
# Processing Record 35 of Set 12 | marzuq
# Processing Record 36 of Set 12 | bargal
# City not found. Skipping
# Processing Record 37 of Set 12 | vega de alatorre
# Processing Record 38 of Set 12 | tacoronte
# Processing Record 39 of Set 12 | villarrobledo
# Processing Record 40 of Set 12 | krasnovishersk
# Processing Record 41 of Set 12 | esmeraldas
# Processing Record 42 of Set 12 | voyvozh
# Processing Record 43 of Set 12 | the valley
# Processing Record 44 of Set 12 | bodden town
# Processing Record 45 of Set 12 | zabol
# Processing Record 46 of Set 12 | tomatlan
# Processing Record 47 of Set 12 | manavalakurichi
# Processing Record 48 of Set 12 | muscle shoals
# Processing Record 49 of Set 12 | bellavista
# Processing Record 0 of Set 13 | hunza
# City not found. Skipping
# Processing Record 1 of Set 13 | kadur
# Processing Record 2 of Set 13 | emerald
# Processing Record 3 of Set 13 | karratha
# Processing Record 4 of Set 13 | gisborne
# Processing Record 5 of Set 13 | coremas
# Processing Record 6 of Set 13 | praia da vitoria
# Processing Record 7 of Set 13 | north platte
# Processing Record 8 of Set 13 | mishan
# Processing Record 9 of Set 13 | margate
# Processing Record 10 of Set 13 | ketchikan
# Processing Record 11 of Set 13 | gao
# Processing Record 12 of Set 13 | parasia
# Processing Record 13 of Set 13 | sartell
# Processing Record 14 of Set 13 | burns lake
# Processing Record 15 of Set 13 | mitsamiouli
# Processing Record 16 of Set 13 | shingu
# Processing Record 17 of Set 13 | hay river
# Processing Record 18 of Set 13 | ondorhaan
# City not found. Skipping
# Processing Record 19 of Set 13 | upplands-vasby
# City not found. Skipping
# Processing Record 20 of Set 13 | kiunga
# Processing Record 21 of Set 13 | novocheboksarsk
# Processing Record 22 of Set 13 | grand river south east
# City not found. Skipping
# Processing Record 23 of Set 13 | sao jose de ribamar
# Processing Record 24 of Set 13 | ambulu
# Processing Record 25 of Set 13 | itarema
# Processing Record 26 of Set 13 | marsh harbour
# Processing Record 27 of Set 13 | ramsi
# Processing Record 28 of Set 13 | davila
# Processing Record 29 of Set 13 | goundam
# Processing Record 30 of Set 13 | muros
# Processing Record 31 of Set 13 | port lincoln
# Processing Record 32 of Set 13 | ushtobe
# Processing Record 33 of Set 13 | kati
# Processing Record 34 of Set 13 | umzimvubu
# City not found. Skipping
# Processing Record 35 of Set 13 | paamiut
# Processing Record 36 of Set 13 | north branch
# Processing Record 37 of Set 13 | chilca
# Processing Record 38 of Set 13 | halalo
# City not found. Skipping
# Processing Record 39 of Set 13 | vangaindrano
# Processing Record 40 of Set 13 | itapetininga
# Processing Record 41 of Set 13 | ampanihy
# Processing Record 42 of Set 13 | flin flon
# Processing Record 43 of Set 13 | kysyl-syr
# Processing Record 44 of Set 13 | rawannawi
# City not found. Skipping
# Processing Record 45 of Set 13 | pimenta bueno
# Processing Record 46 of Set 13 | manta
# Processing Record 47 of Set 13 | vostok
# Processing Record 48 of Set 13 | shinpokh
# Processing Record 49 of Set 13 | pemangkat
# Processing Record 0 of Set 14 | nguiu
# City not found. Skipping
# Processing Record 1 of Set 14 | berezovyy
# Processing Record 2 of Set 14 | san cristobal
# Processing Record 3 of Set 14 | tandalti
# Processing Record 4 of Set 14 | cap malheureux
# Processing Record 5 of Set 14 | cavalcante
# Processing Record 6 of Set 14 | guaruja
# Processing Record 7 of Set 14 | front royal
# Processing Record 8 of Set 14 | otjiwarongo
# Processing Record 9 of Set 14 | birjand
# Processing Record 10 of Set 14 | moose factory
# Processing Record 11 of Set 14 | yerbogachen
# Processing Record 12 of Set 14 | espoo
# Processing Record 13 of Set 14 | coxim
# Processing Record 14 of Set 14 | vallenar
# Processing Record 15 of Set 14 | sokoni
# Processing Record 16 of Set 14 | rio gallegos
# Processing Record 17 of Set 14 | omboue
# Processing Record 18 of Set 14 | antofagasta
# Processing Record 19 of Set 14 | elk point
# Processing Record 20 of Set 14 | talnakh
# Processing Record 21 of Set 14 | asyut
# Processing Record 22 of Set 14 | fare
# Processing Record 23 of Set 14 | estancia
# Processing Record 24 of Set 14 | san quintin
# Processing Record 25 of Set 14 | sorland
# Processing Record 26 of Set 14 | port lavaca
# Processing Record 27 of Set 14 | el rusio
# Processing Record 28 of Set 14 | trofors
# Processing Record 29 of Set 14 | charlottesville
# Processing Record 30 of Set 14 | chisindia
# Processing Record 31 of Set 14 | salinas
# Processing Record 32 of Set 14 | innisfail
# Processing Record 33 of Set 14 | tombouctou
# Processing Record 34 of Set 14 | tillabery
# City not found. Skipping
# Processing Record 35 of Set 14 | san rafael
# Processing Record 36 of Set 14 | el vigia
# Processing Record 37 of Set 14 | bonfim
# Processing Record 38 of Set 14 | kumluca
# Processing Record 39 of Set 14 | cap-aux-meules
# Processing Record 40 of Set 14 | kano
# Processing Record 41 of Set 14 | samastipur
# Processing Record 42 of Set 14 | jinchang
# Processing Record 43 of Set 14 | qianan
# Processing Record 44 of Set 14 | penhold
# Processing Record 45 of Set 14 | sumbe
# Processing Record 46 of Set 14 | uyuni
# Processing Record 47 of Set 14 | afmadu
# City not found. Skipping
# Processing Record 48 of Set 14 | bosaso
# Processing Record 49 of Set 14 | nador
# Processing Record 0 of Set 15 | tshikapa
# Processing Record 1 of Set 15 | general roca
# Processing Record 2 of Set 15 | kutum
# Processing Record 3 of Set 15 | ossora
# Processing Record 4 of Set 15 | piet retief
# Processing Record 5 of Set 15 | aykhal
# Processing Record 6 of Set 15 | tagusao
# Processing Record 7 of Set 15 | benguela
# Processing Record 8 of Set 15 | basco
# Processing Record 9 of Set 15 | karlstad
# Processing Record 10 of Set 15 | puerto vallarta
# Processing Record 11 of Set 15 | noumea
# Processing Record 12 of Set 15 | svetlyy
# Processing Record 13 of Set 15 | tumannyy
# City not found. Skipping
# Processing Record 14 of Set 15 | tessalit
# Processing Record 15 of Set 15 | saint-louis
# Processing Record 16 of Set 15 | linxia
# Processing Record 17 of Set 15 | gemena
# Processing Record 18 of Set 15 | shenxian
# Processing Record 19 of Set 15 | san vicente
# Processing Record 20 of Set 15 | tacuarembo
# Processing Record 21 of Set 15 | verkhnechusovskiye gorodki
# Processing Record 22 of Set 15 | ereymentau
# Processing Record 23 of Set 15 | taylorville
# Processing Record 24 of Set 15 | lahaina
# Processing Record 25 of Set 15 | tulsipur
# Processing Record 26 of Set 15 | sankt veit
# Processing Record 27 of Set 15 | iztapa
# Processing Record 28 of Set 15 | cockburn town
# Processing Record 29 of Set 15 | kadykchan
# City not found. Skipping
# Processing Record 30 of Set 15 | ostrovnoy
# Processing Record 31 of Set 15 | sao jose da coroa grande
# Processing Record 32 of Set 15 | rio cuarto
# Processing Record 33 of Set 15 | sundsvall
# Processing Record 34 of Set 15 | alakurtti
# Processing Record 35 of Set 15 | katobu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0             Lucapa      AO  2021-12-05 00:25:30  -8.4192   20.7447
# 1           Kalmunai      LK  2021-12-05 00:25:30   7.4167   81.8167
# 2            Ushuaia      AR  2021-12-05 00:25:31 -54.8000  -68.3000
# 3          Cape Town      ZA  2021-12-05 00:24:01 -33.9258   18.4232
# 4            Fortuna      US  2021-12-05 00:25:31  40.5982 -124.1573
# 5  Praxedis Guerrero      MX  2021-12-05 00:25:32  31.3667 -106.0167
# 6             Hirara      JP  2021-12-05 00:25:32  24.8000  125.2833
# 7         Nikolskoye      RU  2021-12-05 00:25:33  59.7035   30.7861
# 8             Dagana      MR  2021-12-05 00:25:33  16.5165  -15.5068
# 9        New Norfolk      AU  2021-12-05 00:25:34 -42.7826  147.0587
#
#    Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0     65.59        97          90        1.25     overcast clouds
# 1     76.66        87           3        3.98           clear sky
# 2     49.66        53          40       21.85    scattered clouds
# 3     61.88        91          90        1.99       moderate rain
# 4     51.66        94          90        1.99     overcast clouds
# 5     68.56        24          93        4.05     overcast clouds
# 6     71.46        56          20       13.80          few clouds
# 7     11.01        93         100        6.11     overcast clouds
# 8     80.58        13         100       11.65     overcast clouds
# 9     62.74        42           2        3.00           clear sky

# %%
# Create the output file (CSV).
csv_weather_file= "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
#city_data_df.to_csv(csv_weather_file, index_label="City_ID")
